# %% [markdown]
# # Seaborn
#
# Nessa aula, iremos tratar dos seguintes conteúdos:
# - Seaborn
# - Arquivos de Dados do Seaborn
# - Seaborn x Matplotlib
# - Outras Visualizações do Seaborn
# - Configurações com o Seaborn

# %% [markdown]
# <img src="data:image/jpeg;base64,..." width=600>

# %% [markdown]
# ##

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Quando falamos de visualização de dados, além do __Matplotlib__ uma das principais bibliotecas que temos para utilizar é o __Seaborn__.<br>
# <br>
# O __Seaborn__ é uma biblioteca baseado no próprio _Matplotlib_, mas focada em gráficos de alta performance, ou seja iremos fazer gráficos de uma maneira __mais simples__ e com uma __riqueza maior nas informações__ que queremos passar com os gráficos.

# %% [markdown]
# Para instalar o __Seaborn__ no seu Jupyter Notebooks (quando não tenha já instalado), precisa ser descomentar e rodar o código abaixo:

# %%
#!pip install seaborn

# %% [markdown]
# Primeiro passo será importarmos a bibloteca para o notebook:

# %%
# Carregando a biblioteca
import seaborn as sns

# %% [markdown]
# Além do __Seaborn__, vamos importar algumas outras bibliotecas que serão úteis durante a aula:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##

# %% [markdown]
# ## Arquivos de Datasets do Seaborn

# %% [markdown]
# Utilizando a função __load_dataset__, conseguimos carregar alguns datasets bem conhecidos na aprendizagem de Data Science como por exemplo o _Titanic_, _Tips_ entre outros. Podemos consultar todos os datasets disponíveis usando a função __get_dataset_names__:

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Vamos utilizar o dataset _Iris_ para começar as análises:

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# O _Iris_ é um dataset bem conhecido sobre a classificação de 3 espécies de plantas: _setosa_, _virgínica_ e _versicolor_:<br><br>
# <img src="https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png" width = 800>

# %% [markdown]
# Antes de partirmos para análises e novos gráficos de fato, vamos começar a exercitar as boas práticas quando trabalhamos com análise de dados:

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris[iris['species'] == 'setosa'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %% [markdown]
# Vamos dar uma olhada como está dividido em cada uma das espécies da _Iris_:

# %%
iris['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# ## Seaborn x Matplotlib

# %% [markdown]
# Primeiramente, vamos recordar como fazer um gráfico de dispersão usando o __Matplotlib__:

# %%
# Ajustando a figura
plt.figure(figsize = (12, 8))

# Grafico de Dispersão
plt.scatter('sepal_length', 'sepal_width', data = iris)

# Titulo
plt.title('Comprimento pela Largura da Sépala')

# Titulos dos eixos
plt.xlabel('Comprimento')
plt.ylabel('Largura')

# Colocando uma grade no gráfico
plt.grid()

plt.show()

# %% [markdown]
# No __Seaborn__, podemos fazer o mesmo gráfico utilizando a função __scatterplot__:

# %%
# Ajustando a figura
plt.figure(figsize = (12, 8))

# Grafico de Dispersão
sns.scatterplot(data = iris,
                x = 'sepal_length',
                y = 'sepal_width')

# Titulo
plt.title('Comprimento pela Largura da Sépala')

# Titulos dos eixos
plt.xlabel('Comprimento')
plt.ylabel('Largura')

# Colocando uma grade no gráfico
plt.grid()

plt.show()

# %% [markdown]
# Mas então, a primeira pergunta é: __quais são as vantagens de usar o Seaborn ao invés do Matplotlib?__<br><br>
# Vamos imaginar que queremos fazer o mesmo gráfico mas separando as pelos tipos de _Iris_ (ou seja, separar pelas classes):

# %%
colors = ['red', 'blue', 'green']
species = ['setosa', 'versicolor', 'virginica']

# Ajustando a figura
plt.figure(figsize = (12, 8))

# Grafico de Dispersão
for i in range(0, 3):
    plt.scatter('sepal_length', 
                'sepal_width', 
                data = iris[iris['species'] == species[i]],
                color = colors[i])

# Titulo
plt.title('Comprimento pela Largura da Sépala')

# Titulos dos eixos
plt.xlabel('Comprimento')
plt.ylabel('Largura')

# Colocando uma grade no gráfico
plt.grid()

plt.legend(species)

plt.show()

# %% [markdown]
# No __Seaborn__, sempre que quisermos quebrar um gráfico nas classes basta passar um parâmetro chamado __hue__:

# %%
# Ajustando a figura
plt.figure(figsize = (12, 8))

# Grafico de Dispersão
sns.scatterplot(data = iris,
                x = 'sepal_length',
                y = 'sepal_width',
                hue = 'species')

# Titulo
plt.title('Comprimento pela Largura da Sépala')

# Titulos dos eixos
plt.xlabel('Comprimento')
plt.ylabel('Largura')

# Colocando uma grade no gráfico
plt.grid()

plt.show()

# %% [markdown]
# E o __Seaborn__ nos permite customizar diversas detalhes do nosso gráfico:

# %%
# semente aleatoria
np.random.seed(42)

iris['size'] = np.random.randint(100, 1000, iris.shape[0])

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  size
# 0             5.1          3.5           1.4          0.2     setosa   202
# 1             4.9          3.0           1.4          0.2     setosa   535
# 2             4.7          3.2           1.3          0.2     setosa   960
# 3             4.6          3.1           1.5          0.2     setosa   370
# 4             5.0          3.6           1.4          0.2     setosa   206
# ..            ...          ...           ...          ...        ...   ...
# 145           6.7          3.0           5.2          2.3  virginica   300
# 146           6.3          2.5           5.0          1.9  virginica   939
# 147           6.5          3.0           5.2          2.0  virginica   879
# 148           6.2          3.4           5.4          2.3  virginica   132
# 149           5.9          3.0           5.1          1.8  virginica   147
#
# [150 rows x 6 columns]

# %%
# Ajustando a figura
plt.figure(figsize = (12, 8))

# Paleta de cores
palette = ['#FF6978', '#B1EDE8', '#6D435A']


# Grafico de Dispersão
sns.scatterplot(data = iris,
                x = 'sepal_length',
                y = 'sepal_width',
                hue = 'species',
                palette = palette,
                hue_order = ['virginica', 'versicolor', 'setosa'],
                s = iris['size'])

# Titulo
plt.title('Comprimento pela Largura da Sépala')

# Titulos dos eixos
plt.xlabel('Comprimento')
plt.ylabel('Largura')

# Colocando uma grade no gráfico
plt.grid()

plt.show()

# %% [markdown]
# Um site bem interessante que vocês podem escolher cores para monta o Palette Cutsomizado é o [Coolors](https://coolors.co/)

# %% [markdown]
# ##

# %% [markdown]
# ## Outras Visualizações do Seaborn

# %% [markdown]
# Vamos passar agora, por algumas das principais visualizações que acabam sendo utilizadas do __Seaborn__:

# %% [markdown]
# ### PairPlot

# %%
# Criando um pairplot
sns.pairplot(iris, hue = 'species')

plt.show()

# %%
# Criando um pairplot
sns.pairplot(iris)

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### JointPlot

# %%
sns.jointplot(data = iris, x = 'petal_length', y = 'petal_width')

plt.show()

# %%
sns.jointplot(data = iris, 
              x = 'petal_length', 
              y = 'petal_width',
              hue = 'species')

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### Distplot e Histplot

# %%
sns.distplot(iris['sepal_width'])

plt.show()
# Out:
# C:\Users\ITX Gamer\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data = iris,
            x = 'sepal_width',
            hue = 'species')

plt.show()

# %%
sns.histplot(iris['sepal_width'])

plt.show()

# %%
# Grafico de boxplot
sns.boxplot(data = iris,
            x = 'sepal_length',
            y = 'species')

plt.show()

# %%
# Grafico de boxplot
sns.violinplot(data = iris,
            x = 'sepal_length',
            y = 'species')

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### FacetGrid

# %%
# Criar um FacetGrid
grid = sns.FacetGrid(iris, col = 'species')

# Criando o grafico junto ao Grid
grid.map(sns.histplot, 'sepal_width')

# Mostra o gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### LMPlot

# %%
# Construindo um LMplot
sns.lmplot(data = iris,
           x = 'sepal_length',
           y = 'petal_width')

plt.show()

# %%
# Construindo um LMplot
sns.lmplot(data = iris,
           x = 'sepal_length',
           y = 'petal_width',
           hue = 'species')

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### HeatMap

# %% [markdown]
# O __HeatMap__ (Mapa de Calor) é um gráfico bem interessante quando queremos criar um _Grid_ de variações.<br><br>
# Para usar o HeatMap, vamos definir primeiramente as correlações do DataFrame _Iris_:

# %%
corr = iris.corr()
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width      size
# sepal_length      1.000000    -0.117570      0.871754     0.817941 -0.054322
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126 -0.092223
# petal_length      0.871754    -0.428440      1.000000     0.962865 -0.028870
# petal_width       0.817941    -0.366126      0.962865     1.000000 -0.027346
# size             -0.054322    -0.092223     -0.028870    -0.027346  1.000000

# %% [markdown]
# A função __corr__ mostra como as variáveis do DataFrame estão relacionadas, ou seja o quanto cada variável influência na variação das outras:

# %%
# Criando o HeatMap
sns.heatmap(corr, annot = True)

# Mostrando o gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ### CountPlot e BarPlot

# %%
sns.countplot(data = iris, x = 'species')

plt.show()

# %%
sns.barplot(data = iris, x = 'species', y = 'size')

plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Configurações com o Seaborn

# %% [markdown]
# Vamos aprender algumas outra modificações possíveis para fazermos com os gráficos:

# %%
# Criando um DataFrame com dados simples
df = pd.DataFrame(data = [['caso 1',40, '40%'], 
                          ['caso 2', 30, '30%'], 
                          ['caso 3', 80, '80%']])

# Nomeando as colunas
df.columns = ['caso', 'valor', 'porcentagem']

# Visualiza o DataFrame
df
# Out:
#      caso  valor porcentagem
# 0  caso 1     40         40%
# 1  caso 2     30         30%
# 2  caso 3     80         80%

# %%
# Cria o subplot
fig, ax = plt.subplots(nrows = 1, 
                       ncols = 2, 
                       figsize=(12,6))

# Cria o gráfico sem modificação
sns.barplot(x = df['caso'].values, 
            y = df['valor'].values, 
            ax = ax[0], 
            color = '#C3514E')

# Cria o gráfico que vamos modificar
sns.barplot(x = df['caso'].values, 
            y = df['valor'].values, 
            ax = ax[1], 
            color = '#0C8040')

# Removendo as linhas de Borda do Barplot
ax[1].spines['right'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].spines['left'].set_visible(False)
ax[1].spines['top'].set_visible(False)

# Define um Titulo para o Gráfico do Seaborn
ax[1].set_title('Grafico Customizado\n',  weight ='bold')

# Colocando o Texto do Valor do Gráfico
ax[1].text(0, 42, '40%' , fontsize=11, color='black',verticalalignment='center',horizontalalignment='center')
ax[1].text(1, 32, '30%' , fontsize=11, color='black',verticalalignment='center',horizontalalignment='center')  
ax[1].text(2, 82, '80%' , fontsize=11, color='black',verticalalignment='center',horizontalalignment='center') 

# Remove a Grade da Esquerda
ax[1].tick_params(axis= 'both', bottom=True, labelbottom=True, left = False, labelleft= False)

# Mostra o Gráfico
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Links, Artigos e Referências:

# %% [markdown]
# - [Documentação do Matplotlib](https://matplotlib.org/), documentação onde vocês podem encontrar mais informações sobre os gráficos do Matplotlib;
# - [Documentação do Seaborn](https://seaborn.pydata.org/), documentação onde vocês podem encontrar mais informações sobre os gráficos do Seaborn;
# - [Beautiful Plots with Python and Seaborn](https://betterprogramming.pub/beautiful-plots-with-python-and-seaborn-9d05c9ead6ed), artigo publicado no blog Better Programming
